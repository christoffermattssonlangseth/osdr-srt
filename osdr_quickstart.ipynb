# %% [markdown]
# # OSDR Quickstart
#
# Select the kernel named **Python (osdr)** (or your conda kernel name) before running.

# %%
# Verify the package import and basic utility
from tdm.utils import microns
microns(1)
